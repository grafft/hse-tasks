# %% [markdown]
# В начале - вспомним нейронные сети из предыдущего модуля - https://goo.gl/forms/V8ByVYtJJ6lJCc0Q2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# # Нормальное распределение

# %% [markdown]
# Сгенерировать выборку из нормально распределённой случайной величины с параметрами $\mu=2.0$ и $\sigma=0.5$:

# %%
mu = 2.0
sigma = 0.5

# зададим нормально распределенную случайную величину

# сгенерируем 10 значений

# %% [markdown]
# Вернуть значение функции распределения нормальной случайной величины в точке, соответствующей её аргументу:

# %%
#

# %% [markdown]
# Построим график функции распределения:

# %%
###

# %% [markdown]
# А теперь вычислим значение функции плотности вероятности нормального распределения в заданной точке:

# %%
###

# %% [markdown]
# Построим график функции плотности вероятности:

# %%
###

# %% [markdown]
# # Равномерное распределение на отрезке

# %% [markdown]
# Сгенерировать выборку из случайной величины, имеющей равномерное распределение на отрезке $[a,b]$:

# %%
a = 1
b = 4

# в этой функции задается левая граница и масштаб, а не левая и правая границы:

# %% [markdown]
# Вычислим значения функций распределения и плотностей:

# %%
# график

# %%
# график

# %% [markdown]
# # Распределение Бернулли

# %% [markdown]
# Генерация выборок из распределения Бернулли с заданным параметром $p$:

# %%
#

# %% [markdown]
# # Биномиальное распределение

# %% [markdown]
# Генерация выборок из биномиального распределения:

# %%
#

# %% [markdown]
# Первый аргумент функции binom — значение параметра $n$, второй — параметра $p$.
#
# Функция распределения:

# %%
#

# %% [markdown]
# Функция вероятности ```pmf``` для дискретных случайных величин заменяет функцию плотности ```pdf```:

# %%
# точечный график

# %% [markdown]
# Посмотрим, как ведут себя биномиально распределенные величины при разных значениях параметров:

# %%
x = np.linspace(0,45,46)
for N in [20, 30]:
    for p in [0.2, 0.7]:
        #plt.step for cdf
# legend
# Out:
#   File "<ipython-input-17-76f59c6d00d6>", line 5
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
x = np.linspace(0,45,46)
symbols = iter(['o', 's', '^', '+'])
for N in [20, 30]:
    for p in [0.2, 0.8]:
        #plt.step for pmf
# legend
# Out:
#   File "<ipython-input-18-c46687376aa3>", line 7
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Распределение Пуассона

# %% [markdown]
# Генерация выборок из распределения Пуассона с параметром $\lambda$:

# %%
poisson_rv = sts.poisson(5)
poisson_rv.rvs(10)
# Out:
# array([ 4,  5,  6,  3, 12,  5,  7,  4, 11,  1])

# %%
x = np.linspace(0,30,31)
for l in [1, 5, 10, 15]:
    #plt.step for cdf
# legend
# Out:
#   File "<ipython-input-20-6e7323447b25>", line 4
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
x = np.linspace(0,30,31)

symbols = iter(['o', 's', '^', '+'])
for l in [1, 5, 10, 15]:
    #plt.step for pmf
# legend
# Out:
#   File "<ipython-input-21-c1ff75df80ae>", line 6
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Дискретное распределение общего вида

# %% [markdown]
# Чтобы сгенерировать дискретную случайную величину общего вида, нужно задать множество её значений и соответствующих вероятностей и использовать функцию ```numpy.random.choice```:

# %%
elements = np.array([1, 5, 12])
probabilities = [0.05, 0.7, 0.25]
np.random.choice(elements, 10, p=probabilities)
# Out:
# array([5, 5, 1, 5, 5, 5, 1, 5, 5, 5])

# %% [markdown]
# # Другие распределения

# %% [markdown]
# Существует большое количество других стандартных семейств распределений, многие из которых также можно генерировать в Питоне.
# Например, распределение хи-квадрат $\chi^2_k$, имеющее наутральный параметр $k$, который называется числом степеней свободы:

# %%
x = np.linspace(0,30,100)
for k in [1, 2, 3, 4, 6, 9]:
        #plt.step for cdf
# legend
# Out:
#   File "<ipython-input-23-8cf486837ce9>", line 4
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
x = np.linspace(0,30,100)
for k in [1, 2, 3, 4, 6, 9]:
    #plt.step for pdf
# legend
# Out:
#   File "<ipython-input-24-598470bdcf0e>", line 4
#     # legend
#             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# Полный список функций SciPy для работы со всеми распределениями можно найти [тут](http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html).
