# %%
import pandas as pd
import xgboost as xgb

# %%
df = pd.read_csv('train_data.csv')

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   26      student   single        high.school       no      no   no
# 1   46       admin.  married  university.degree       no     yes   no
# 2   49  blue-collar  married           basic.4y  unknown     yes  yes
# 3   31   technician  married  university.degree       no      no   no
# 4   42    housemaid  married  university.degree       no     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   jun         mon       901         1    999         0
# 1   cellular   aug         tue       208         2    999         0
# 2  telephone   jun         tue       131         5    999         0
# 3   cellular   jul         tue       404         1    999         0
# 4  telephone   nov         mon        85         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
dft = pd.read_csv('train_target.csv', header=None)

# %%
dft.head()
# Out:
#    0
# 0  1
# 1  0
# 2  0
# 3  0
# 4  0

# %%
df.shape, dft.shape
# Out:
# ((27595, 20), (27595, 1))

# %%
dft[0].value_counts()
# Out:
# 0    24481
# 1     3114
# Name: 0, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.values, dft.values, test_size=0.33, random_state=42)

# %%
xgb = xgb.XGBoostClassifier()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1da1e6821e84> in <module>()
# ----> 1 xgb = xgb.XGBoostClassifier()
#
# AttributeError: module 'xgboost' has no attribute 'XGBoostClassifier'
