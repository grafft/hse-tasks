# %%
import sys
import random
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from pymystem3 import Mystem
from gensim.models import Phrases
from gensim import corpora, models,similarities
import json
import logging
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# C:\Users\sanek\Anaconda3\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # Вычисляем tf-idf

# %%
random.seed(1228)

# %% [markdown]
# В папке data лежат 28 файлов, в каждом файле по 100 текстов на одну тему

# %%
event_path = "./data/"

m = Mystem()
regex = re.compile("[А-Яа-яёA-Za-z]+")
mystopwords = stopwords.words('russian') + stopwords.words('english') + stopwords.words('german')
mystopwords += ['это', 'наш', 'т', 'д', 'этот', 'который', 'свой', 'наш', 'мой', 'твой', 'тот', 'делать', 'друг', 'сделать', 
                'любой', 'каждый', 'самый', 'хотеть', 'мочь', 'ваш', 'сей', 'весь', 'очень', 'день', 'год', 'м',
               'ч', 'руб', 'л', 'например', 'становиться', 'http', 'www', 'https', 'vk', 'vkontakte', 'vk', 'com', 'ru',
               'январь', 'февраль','март','апрель','май','июнь','июль','август','сентябрь','октябрь','ноябрь','декабрь']

# %% [markdown]
# Опреляем все необходимые функции:

# %%
def remove_url(text):
    text =  re.sub(r"http\S+", "", text).strip()
    text =  re.sub(r"vk\S+", "", text).strip()
    text =  re.sub(r"https\S+", "", text).strip()
    text =  re.sub(r"VK\S+", "", text).strip()
    return text

def words_only(text, regex=regex):
    return " ".join(regex.findall(text))

def remove_stopwords(text, mystopwords = mystopwords):
    try:
        return " ".join([token for token in text.split() if (token not in mystopwords) and (token.count(token[0]) != len(token))])
    except:
        return ""

# %%
def lemmatize(text, mystem=m):
    try:
        return "".join(m.lemmatize(text)).strip()  
    except:
        return ""

def length_filter(text, n_words = 3):
    tokens = text.split()
    if len(tokens) > n_words:
        return text
    else:
        return ""

def add_bigrams(texts, min_count = 5): # запись: "дональд_трамп"
    tokens = [text.split() for text in texts]
    bigram = Phrases(tokens, min_count = min_count)
    for i in range(len(tokens)):
        for token in bigram[tokens[i]]:
            if '_' in token:
                tokens[i].append(token)
    return [' '.join(text) for text in tokens]

# %%
def news2df(): # разделение текстов из файла, создание data frame
    data = []
    for i in range(1,29):
        with open(event_path + str(i) + '.txt', encoding='utf8') as infile:
            lines = infile.readlines()
        texts = []
        text = ''
        for j in range(13, len(lines)):
            if lines[j] != '\n':
                text += ' '+lines[j].strip()
            else:
                texts.append(text)
                text = ''
            if j == len(lines)-1:
                texts.append(text)
        for text in texts:
            data.append([i, text])
    text_df = pd.DataFrame.from_records(data, columns = ['event_id','text'])  
    return text_df

# %% [markdown]
# Вся предобработка входных данных:

# %%
def preprocess(df):
    df.text = df.text.str.lower()
    df.text = df.text.apply(remove_url)
    df.text = df.text.apply(words_only)
    df.text.replace('', np.nan, inplace=True)
    df.dropna(subset=['text'], inplace=True)
    df.text = df.text.apply(remove_stopwords)
    df.text = df.text.apply(lemmatize)
    df.text = df.text.apply(remove_stopwords)  
    df.text = add_bigrams(df.text)
    return df

# %% [markdown]
# В events2017.xlsx записаны темы текстов

# %%
converters = {0: str, 1:str, 2:str}
event_df = pd.read_excel(event_path+"events2017.xlsx",  header=None, sheetname = 0, converters=converters)

# %%
event_df = event_df.rename(index=str, columns={0: 'id', 1: "date", 2: "name"})

# %%
event_df.head() # 28 строк с названиями тем
# Out:
#   id                 date                                               name
# 0  1  2017-01-10 00:00:00  Власти Петербурга согласились передать РПЦ Иса...
# 1  2  2017-01-20 00:00:00  Дональд Трамп вступил в должность президента США.
# 2  3  2017-02-20 00:00:00  Скоропостижно скончался постпред России при ОО...
# 3  4  2017-03-02 00:00:00           Вышел фильм Навального «он Вам не димон»
# 4  5  2017-03-14 00:00:00  CNN показала фильм «Владимир Путин — самый вли...

# %%
event_df.to_csv('./events.csv', index = False)

# %% [markdown]
# Разделяем и обрабатываем тексты:

# %%
news_df = news2df()
news_df.head()
news_df = preprocess(news_df)
news_df.to_csv('./news.csv')


news_df = pd.read_csv('./news.csv',
                     usecols = ['event_id','text'],
                     dtype = {'event_id':'str', 'text':'str'})
event_df = pd.read_csv('./events.csv',
                     usecols = ['id', 'date', 'name'],
                     dtype = {'id':'str', 'date':'str', 'name':'str'})
# Out:
# C:\Users\sanek\Anaconda3\lib\site-packages\gensim\models\phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-090786c36785> in <module>()
#       7 news_df = pd.read_csv('./news.csv',
#       8                      usecols = ['event_id','text'],
# ----> 9                      dtype = {'event_id':'str', 'text':'str'})
#      10 event_df = pd.read_csv('./events.csv',
#      11                      usecols = ['id', 'date', 'name'],
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1003                 raise ValueError('skipfooter not supported for iteration')
#    1004
# -> 1005         ret = self._engine.read(nrows)
#    1006
#    1007         if self.options.get('as_recarray'):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1746     def read(self, nrows=None):
#    1747         try:
# -> 1748             data = self._reader.read(nrows)
#    1749         except StopIteration:
#    1750             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read (pandas\_libs\parsers.c:10862)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas\_libs\parsers.c:11138)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas\_libs\parsers.c:12175)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data (pandas\_libs\parsers.c:14136)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14658)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:16612)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xef in position 0: invalid continuation byte

# %% [markdown]
# Получили по 100 строк на каждую из 28 тем

# %%
news_df
# Out:
#      event_id                                               text
# 0           1  петербург проходить митинг против передача иса...
# 1           1  lenta co москва ситуация передача исаакиевский...
# 2           1  аргумент факт aif москва оппозиция проводить м...
# 3           1  google новость топ москва акция против передач...
# 4           1  газета москва московский патриархия прокоммент...
# 5           1  top real estate topre москва петербуржец проте...
# 6           1  findnews москва полиция насчитывать участник а...
# 7           1  правда info pravda info москва ленинградец соб...
# 8           1  голос америка golos ameriki москва исаакиевски...
# 9           1  выбор народ vybor naroda org москва петербург ...
# 10          1  flynews москва interfax news акция против пере...
# 11          1  коммерсант новость online москва протестный эк...
# 12          1  весть москва петербуржец протестовать против п...
# 13          1  findnews москва исаакиевский собор проходить а...
# 14          1  радио свобода svoboda org москва петербург про...
# 15          1  иа regnum москва исаакиевский собор проходить ...
# 16          1  google новость топ москва оппозиция проводить ...
# 17          1  преступный россия crimerussia москва transpare...
# 18          1  суть событие argumentiru москва тысяча человек...
# 19          1  business fm bfm москва битва исаакиевский собо...
# 20          1  аргумент неделi argumenti москва петербуржец п...
# 21          1  google новость топ москва transparency interna...
# 22          1  new times newtimes москва new times санкт пете...
# 23          1  profi news москва противник передача исаакиевс...
# 24          1  открытый россия openrussia org москва митинг п...
# 25          1  риа новость москва противник передача исаакиев...
# 26          1  газета москва акция протест против передача ис...
# 27          1  vistanews москва петербург протестовать против...
# 28          1  национальный служба новость nsn fm москва пете...
# 29          1  ислам news islamnews москва петербург проходит...
# ...       ...                                                ...
# 1900       28  тасс москва кандидат губернатор новгородский о...
# 1901       28  тасс москва выборы губернатор пфо первый жалоб...
# 1902       28  тасс москва выборы севастополь кубань проголос...
# 1903       28  тасс москва международный эксперт положительно...
# 1904       28  тасс москва эксперт отмечать активность молодо...
# 1905       28  тасс москва минобороны большой часть российски...
# 1906       28  российский газета москва пятеро кандидат манда...
# 1907       28  коммерсант kommersant москва единообразный гол...
# 1908       28  kp москва выборы москва слишком молодой гамбур...
# 1909       28  kp москва житель район саратовский область рас...
# 1910       28  московский комсомолец москва москвич неохотно ...
# 1911       28  рбк rbc москва мосгоризбирком называть провока...
# 1912       28  рбк rbc москва путин проголосовать муниципальн...
# 1913       28  рбк rbc москва регион россия начинаться единый...
# 1914       28  рбк rbc москва голосование выборы центральный ...
# 1915       28  lenta москва политолог богданов объявлять наме...
# 1916       28  lenta москва избирательный участок проверять д...
# 1917       28  lenta москва избирательный участок бурятия поп...
# 1918       28  lenta москва голосование выборы начинаться рос...
# 1919       28  lenta москва наблюдатель москва пресекать вбро...
# 1920       28  lenta москва бурятия закрываться избирательный...
# 1921       28  lenta москва путин проголосовать муниципальный...
# 1922       28  lenta москва мосгоризбирком подсчитывать число...
# 1923       28  lenta москва жириновский зюганов проголосовать...
# 1924       28  lenta москва явка выборы севастополь четыре ча...
# 1925       28  lenta москва кандидат депутат москва покусать ...
# 1926       28  lenta москва избирком оценивать явка выборы гл...
# 1927       28  lenta москва кандидат столичный депутат пожало...
# 1928       28  lenta москва медведев припоминать избранный гу...
# 1929       28  lenta москва жириновский призывать перенести в...
#
# [1930 rows x 2 columns]

# %% [markdown]
# Внутри леммы и биграммы

# %%
news_df.text[112]
# Out:
# 'правдинформ trueinform москва трамп вступать должность президент сша дональд трамп инаугурация сша риа новость избранный президент дональд трамп прибывать инаугурация капитолий вашингтон вашингтон янва риа новость дональд трамп вступать должность президент сша приводить присяга председатель верховный суд сша джон робертс бизнесмен трамп президент сша сменить пост глава государство барак обама завершать срок полномочие дональд трамп торжественно клясться добросовестно выполнять обязанность президент соединять штат полный мера сила поддерживать охранять защищать конституция соединять штат произносить трамп подымать правый рука полагать левый рука библия первый библия подарить мать честь окончание воскресный школа второй принадлежать му президент сша авраам линкольн инаугурация глава государство принимать участие праздничный обед сенатор конгрессмен затем принимать торжественный парад вместе первый леди мелания трамп посещать несколько бал ria world html правдинформ_trueinform вступать_должность президент_сша дональд_трамп риа_новость избранный_президент дональд_трамп риа_новость дональд_трамп вступать_должность президент_сша приводить_присяга председатель_верховный президент_сша пост_глава барак_обама дональд_трамп соединять_штат полный_мера соединять_штат президент_сша глава_государство принимать_участие первый_леди'

# %% [markdown]
# Объединяем все тексты одной темы

# %%
N_event = len(event_df)

merged_news = []
gb = news_df.groupby('event_id')    
for event in range(N_event):
    text = ''
    sample = gb.get_group(str(event+1))
    text = ' '.join(sample.text.tolist())
    merged_news.append(text)

# %% [markdown]
# Вычисляем tfidf

# %%
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 0)
tfidf_matrix =  tfidf.fit_transform(merged_news)
feature_names = tfidf.get_feature_names() 
data = []
dense = tfidf_matrix.todense()
for i in range(N_event):
    text = dense[i].tolist()[0]
    phrase_scores = [pair for pair in zip(range(0, len(text)), text) if pair[1] > 0]
    sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
    phrases = []
    for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:50]:
        phrases.append(phrase)
    data.append([i, ' '.join(phrases), event_df.name.tolist()[i]])
df = pd.DataFrame.from_records(data, columns = ['event_id','terms','event_name'])
df.to_csv('./event_dict.csv', index = False)

# %% [markdown]
# Результат:

# %%
for i in range (0, 28):
    print (i)
    print (df.event_name[i])
    print (df.terms[i])
# Out:
# 0
# Власти Петербурга согласились передать РПЦ Исаакиевский собор.
# собор исаакиевский рпц передача исаакиевский_собор передача_исаакиевский петербург музей собор_рпц церковь музейный санкт безвозмездный передача_собор православный акция резник пользование против вишневский против_передача храм буров полтавченко депутат санкт_петербург православный_церковь исаакий максим_резник алексей_ковалев борис_вишневский ковалев встреча_депутат русский_православный безвозмездный_пользование религиозный передавать губернатор исаакиевский_площадь митинг николай_буров решение собираться проходить русский москва человек встреча памятник георгий
# 1
# Дональд Трамп вступил в должность президента США.
# инаугурация трамп президент дональд сша дональд_трамп президент_сша обама россия избранный_президент избранный инаугурация_трамп первый российский новый время церемония страна республиканец инаугурационный барак цб мир правительство человек демократ инаугурация_дональд суд вашингтон кабинет назначение американский барак_обама инаугурация_го москва дело должность сенат присяга отношение цена американец дом банк капитолий кс юкос белый америка рынок
# 2
# Скоропостижно скончался постпред России при ООН Виталий Чуркин.
# чуркин виталий_чуркин оон виталий дипломат виталия постпред россия_оон постоянный_представитель умирать_виталий россия смерть виталия_чуркин умирать причина_смерть мид йорк нью постоянный представитель соболезнование скончаться российский нью_йорк москва рф причина дипломатический цветок скоропостижный кончина российский_дипломат мид_рф посол постпред_россия мгимо выражать память_виталия скоропостижный_скончаться пост иванович выдающийся жизнь_рабочий отстаивать виталий_иванович сша постпред_оон близкий_виталий рабочий жизнь
# 3
# Вышел фильм Навального «он Вам не димон»
# медведев фонд фбк дар расследование яхта елисеев усадьба виноградник навальный фонд_дар плес агрокомплекс усманов мансурово дмитрий_медведев офшор премьер дмитрий соцгоспроект рублевка однокурсник резиденция компания рубль илья_елисеев цертум схема недвижимость премьер_министр дача фирма миллиард министр земля некоммерческий димон принадлежать кроссовок алишер миловка участок имущество инвест расследование_фбк градислава коррупция олигарх скалистый фонд_поддержка
# 4
# CNN показала фильм «Владимир Путин — самый влиятельный человек в мире».
# фильм путин cnn закария могущественный владимир президент телеканал_cnn владимир_путин мир россия геббельс фарид российский человек сша киреев холодный понимать трамп американский холодный_война страх война дрезден ремник родионов давать дмитрий телеканал интеллектуал влиятельный название автор фан эпоха дмитрий_песок новоизбранный новоизбранный_президент одиозный предательство фейк хиллари_клинтон песок противник жизнь эксперт восстание геополитический фабрика
# 5
# Умер Дэвид рокфеллер
# рокфеллер дэвид_рокфеллер дэвид миллиардер умирать нью умирать_дэвид йорк пересадка chase сердце банк скончаться джон_рокфеллер покантико джон нью_йорк влиятельный династия бильдербергский бильдербергский_клуб сша oil сон университет доллар международный жизнь семья гарвардский внук bank долларовый умирать_сон штат_нью гарвардский_университет старший мир американский_миллиардер возраст трехсторонний_комиссия первый мировой manhattan standard_oil трехсторонний история_долларовый мировой_правительство рокфеллер_умирать рокфеллеровский
